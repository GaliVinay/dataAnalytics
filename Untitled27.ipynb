# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(np.random.rand(1000, 1), index=pd.date_range(start='2025-09-03', periods=1000) , columns=['data'])

# %%
df
# Out:
#                 data
# 2025-09-03  0.749015
# 2025-09-04  0.714936
# 2025-09-05  0.834827
# 2025-09-06  0.250992
# 2025-09-07  0.492119
# ...              ...
# 2028-05-25  0.239046
# 2028-05-26  0.262409
# 2028-05-27  0.151054
# 2028-05-28  0.010887
# 2028-05-29  0.469251
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.cumsum().plot()
# Out:
# <Axes: >

# %%
df['data1'] = df.data.cumsum()

# %%
df['data2'] =df['data']**2

# %%
df
# Out:
#                 data     data2
# 2025-09-03  0.749015  0.561023
# 2025-09-04  0.714936  0.511134
# 2025-09-05  0.834827  0.696936
# 2025-09-06  0.250992  0.062997
# 2025-09-07  0.492119  0.242181
# ...              ...       ...
# 2028-05-25  0.239046  0.057143
# 2028-05-26  0.262409  0.068859
# 2028-05-27  0.151054  0.022817
# 2028-05-28  0.010887  0.000119
# 2028-05-29  0.469251  0.220197
#
# [1000 rows x 2 columns]

# %%
df['data3'] = df['data'].apply( lambda x : np.log10(x))

# %%
df
# Out:
#                 data     data2     data3       data1
# 2025-09-03  0.749015  0.561023 -0.125510    0.749015
# 2025-09-04  0.714936  0.511134 -0.145733    1.463951
# 2025-09-05  0.834827  0.696936 -0.078404    2.298778
# 2025-09-06  0.250992  0.062997 -0.600339    2.549770
# 2025-09-07  0.492119  0.242181 -0.307930    3.041889
# ...              ...       ...       ...         ...
# 2028-05-25  0.239046  0.057143 -0.621518  496.024283
# 2028-05-26  0.262409  0.068859 -0.581021  496.286693
# 2028-05-27  0.151054  0.022817 -0.820869  496.437746
# 2028-05-28  0.010887  0.000119 -1.963094  496.448633
# 2028-05-29  0.469251  0.220197 -0.328595  496.917885
#
# [1000 rows x 4 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function to generate Bézier curve points for thick petals
def bezier_curve(points, num=100):
    t = np.linspace(0, 1, num)
    curve = np.array([
        (1 - t) ** 3 * points[0] +
        3 * (1 - t) ** 2 * t * points[1] +
        3 * (1 - t) * t ** 2 * points[2] +
        t ** 3 * points[3]
        for t in t
    ])
    return curve[:, 0], curve[:, 1]

# Function to draw a thick lotus petal
def draw_petal(ax, angle, color, scale=1.0):
    petal_points = np.array([
        [-0.6, 0],   # Wider base left
        [0.9, 1.8],  # Control point 1 (right curve)
        [-0.9, 1.8], # Control point 2 (left curve)
        [0, 3.0]     # Tip of the petal (higher for thickness)
    ]) * scale

    x, y = bezier_curve(petal_points)

    # Rotate petals
    angle_rad = np.radians(angle)
    x_rot = x * np.cos(angle_rad) - y * np.sin(angle_rad)
    y_rot = x * np.sin(angle_rad) + y * np.cos(angle_rad)

    ax.fill(x_rot, y_rot, color=color, alpha=0.9, edgecolor="black", linewidth=0.7)

# Function to draw lotus leaves
def draw_lotus_leaves(ax):
    for scale, color, x_offset, y_offset in [
        (2.5, "darkgreen", 0, -2.8), 
        (2.8, "seagreen", -2, -3.2),
        (3.0, "forestgreen", 2, -3.5)
    ]:
        leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)
        ax.add_patch(leaf)

# Function to draw the full lotus flower
def draw_realistic_lotus():
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(-4, 4)
    ax.set_ylim(-4, 4)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    sns.set_style("white")

    # Draw lotus leaves
    draw_lotus_leaves(ax)

    # Draw multiple layers of petals
    for scale, color, offset in [
        (1.2, "pink", 0), 
        (1.0, "lightpink", 15), 
        (0.8, "palevioletred", 30)
    ]:
        for angle in np.linspace(0, 360, 8, endpoint=False):
            draw_petal(ax, angle + offset, color, scale)

    # Draw the center of the flower
    ax.scatter(0, 0, s=800, color="yellow", edgecolor="gold", linewidth=2, zorder=3)

    plt.title(" Sayani its for u ", fontsize=14, fontweight="bold")
    plt.show()

# Call function to draw the lotus
draw_realistic_lotus()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4348\673687009.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function to generate Bézier curve points for thick petals
def bezier_curve(points, num=100):
    t = np.linspace(0, 1, num)
    curve = np.array([
        (1 - t) ** 3 * points[0] +
        3 * (1 - t) ** 2 * t * points[1] +
        3 * (1 - t) * t ** 2 * points[2] +
        t ** 3 * points[3]
        for t in t
    ])
    return curve[:, 0], curve[:, 1]

# Function to draw a thick lotus petal with more control points
def draw_petal(ax, angle, color, scale=1.0):
    petal_points = np.array([
        [-0.6, 0],   # Wider base left
        [0.9, 1.8],  # Control point 1 (right curve)
        [-0.9, 1.8], # Control point 2 (left curve)
        [0, 3.0]     # Tip of the petal (higher for thickness)
    ]) * scale

    x, y = bezier_curve(petal_points)

    # Rotate petals
    angle_rad = np.radians(angle)
    x_rot = x * np.cos(angle_rad) - y * np.sin(angle_rad)
    y_rot = x * np.sin(angle_rad) + y * np.cos(angle_rad)

    # Add gradient shading to the petals
    ax.fill(x_rot, y_rot, color=color, alpha=0.9, edgecolor="black", linewidth=0.7)
    ax.plot(x_rot, y_rot, color="black", linewidth=0.5, alpha=0.5)

# Function to draw lotus leaves with veins
def draw_lotus_leaves(ax):
    for scale, color, x_offset, y_offset in [
        (2.5, "darkgreen", 0, -2.8), 
        (2.8, "seagreen", -2, -3.2),
        (3.0, "forestgreen", 2, -3.5)
    ]:
        leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)
        ax.add_patch(leaf)

        # Add veins to the leaves
        for i in range(5):
            vein = plt.Line2D(
                [x_offset - scale * 0.8 + i * 0.4, x_offset + scale * 0.8 - i * 0.4],
                [y_offset - scale * 0.2, y_offset + scale * 0.2],
                color="black", alpha=0.3, linewidth=0.5
            )
            ax.add_line(vein)

# Function to draw the full lotus flower with more detail
def draw_realistic_lotus():
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(-4, 4)
    ax.set_ylim(-4, 4)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    sns.set_style("white")

    # Draw lotus leaves
    draw_lotus_leaves(ax)

    # Draw multiple layers of petals with gradients
    for scale, color, offset in [
        (1.2, "pink", 0), 
        (1.0, "lightpink", 15), 
        (0.8, "palevioletred", 30)
    ]:
        for angle in np.linspace(0, 360, 8, endpoint=False):
            draw_petal(ax, angle + offset, color, scale)

    # Draw the center of the flower with more detail
    ax.scatter(0, 0, s=800, color="yellow", edgecolor="gold", linewidth=2, zorder=3)
    for i in range(50):
        angle = np.random.uniform(0, 360)
        radius = np.random.uniform(0, 0.5)
        x = radius * np.cos(np.radians(angle))
        y = radius * np.sin(np.radians(angle))
        ax.scatter(x, y, s=10, color="gold", edgecolor="darkgoldenrod", linewidth=0.5, zorder=4)

    plt.title("Realistic Lotus Flower", fontsize=14, fontweight="bold")
    plt.show()

# Call function to draw the lotus
draw_realistic_lotus()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4348\3159959362.py:44: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function to generate Bézier curve points for smooth petals
def bezier_curve(points, num=100):
    t = np.linspace(0, 1, num)
    curve = np.array([
        (1 - t) ** 3 * points[0] +
        3 * (1 - t) ** 2 * t * points[1] +
        3 * (1 - t) * t ** 2 * points[2] +
        t ** 3 * points[3]
        for t in t
    ])
    return curve[:, 0], curve[:, 1]

# Function to draw a smooth lotus petal
def draw_petal(ax, angle, color, scale=1.0):
    # Adjusted control points for a more natural petal shape
    petal_points = np.array([
        [-0.5, 0],   # Base of the petal (wider)
        [0.5, 1.5],  # Control point 1 (right curve)
        [-0.5, 2.0], # Control point 2 (left curve)
        [0, 3.0]     # Tip of the petal (higher for a natural curve)
    ]) * scale

    x, y = bezier_curve(petal_points)

    # Rotate petals
    angle_rad = np.radians(angle)
    x_rot = x * np.cos(angle_rad) - y * np.sin(angle_rad)
    y_rot = x * np.sin(angle_rad) + y * np.cos(angle_rad)

    # Add gradient shading to the petals
    ax.fill(x_rot, y_rot, color=color, alpha=0.9, edgecolor="black", linewidth=0.7)
    ax.plot(x_rot, y_rot, color="black", linewidth=0.5, alpha=0.5)

# Function to draw lotus leaves with veins
def draw_lotus_leaves(ax):
    for scale, color, x_offset, y_offset in [
        (2.5, "darkgreen", 0, -2.8), 
        (2.8, "seagreen", -2, -3.2),
        (3.0, "forestgreen", 2, -3.5)
    ]:
        leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)
        ax.add_patch(leaf)

        # Add veins to the leaves
        for i in range(5):
            vein = plt.Line2D(
                [x_offset - scale * 0.8 + i * 0.4, x_offset + scale * 0.8 - i * 0.4],
                [y_offset - scale * 0.2, y_offset + scale * 0.2],
                color="black", alpha=0.3, linewidth=0.5
            )
            ax.add_line(vein)

# Function to draw the full lotus flower with more detail
def draw_realistic_lotus():
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(-4, 4)
    ax.set_ylim(-4, 4)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    sns.set_style("white")

    # Draw lotus leaves
    draw_lotus_leaves(ax)

    # Draw multiple layers of petals with gradients
    for scale, color, offset in [
        (1.2, "pink", 0), 
        (1.0, "lightpink", 15), 
        (0.8, "palevioletred", 30)
    ]:
        for angle in np.linspace(0, 360, 8, endpoint=False):
            draw_petal(ax, angle + offset, color, scale)

    # Draw the center of the flower with more detail
    ax.scatter(0, 0, s=800, color="yellow", edgecolor="gold", linewidth=2, zorder=3)
    for i in range(50):
        angle = np.random.uniform(0, 360)
        radius = np.random.uniform(0, 0.5)
        x = radius * np.cos(np.radians(angle))
        y = radius * np.sin(np.radians(angle))
        ax.scatter(x, y, s=10, color="gold", edgecolor="darkgoldenrod", linewidth=0.5, zorder=4)

    plt.title("Sayani it is for You ", fontsize=14, fontweight="bold")
    plt.show()

# Call function to draw the lotus
draw_realistic_lotus()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4348\1821184912.py:45: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function to generate Bézier curve points for petals with a round pinched tip
def bezier_curve(points, num=100):
    t = np.linspace(0, 1, num)
    curve = np.array([
        (1 - t) ** 3 * points[0] +
        3 * (1 - t) ** 2 * t * points[1] +
        3 * (1 - t) * t ** 2 * points[2] +
        t ** 3 * points[3]
        for t in t
    ])
    return curve[:, 0], curve[:, 1]

# Function to draw a lotus petal with a round pinched tip
def draw_petal(ax, angle, color, scale=1.0):
    # Adjusted control points for a round pinched tip
    petal_points = np.array([
        [-0.5, 0],   # Base of the petal (wider)
        [0.5, 1.5],  # Control point 1 (right curve)
        [-0.5, 2.5], # Control point 2 (left curve, creates the pinch)
        [0, 3.0]     # Tip of the petal (rounded and pinched)
    ]) * scale

    x, y = bezier_curve(petal_points)

    # Rotate petals
    angle_rad = np.radians(angle)
    x_rot = x * np.cos(angle_rad) - y * np.sin(angle_rad)
    y_rot = x * np.sin(angle_rad) + y * np.cos(angle_rad)

    # Add gradient shading to the petals
    ax.fill(x_rot, y_rot, color=color, alpha=0.9, edgecolor="black", linewidth=0.7)
    ax.plot(x_rot, y_rot, color="black", linewidth=0.5, alpha=0.5)

# Function to draw lotus leaves with veins
def draw_lotus_leaves(ax):
    for scale, color, x_offset, y_offset in [
        (2.5, "darkgreen", 0, -2.8), 
        (2.8, "seagreen", -2, -3.2),
        (3.0, "forestgreen", 2, -3.5)
    ]:
        leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)
        ax.add_patch(leaf)

        # Add veins to the leaves
        for i in range(5):
            vein = plt.Line2D(
                [x_offset - scale * 0.8 + i * 0.4, x_offset + scale * 0.8 - i * 0.4],
                [y_offset - scale * 0.2, y_offset + scale * 0.2],
                color="black", alpha=0.3, linewidth=0.5
            )
            ax.add_line(vein)

# Function to draw the full lotus flower with round pinched petals
def draw_realistic_lotus():
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(-4, 4)
    ax.set_ylim(-4, 4)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    sns.set_style("white")

    # Draw lotus leaves
    draw_lotus_leaves(ax)

    # Draw multiple layers of petals with gradients
    for scale, color, offset in [
        (1.2, "pink", 0), 
        (1.0, "lightpink", 15), 
        (0.8, "palevioletred", 30)
    ]:
        for angle in np.linspace(0, 360, 8, endpoint=False):
            draw_petal(ax, angle + offset, color, scale)

    # Draw the center of the flower with more detail
    ax.scatter(0, 0, s=800, color="yellow", edgecolor="gold", linewidth=2, zorder=3)
    for i in range(50):
        angle = np.random.uniform(0, 360)
        radius = np.random.uniform(0, 0.5)
        x = radius * np.cos(np.radians(angle))
        y = radius * np.sin(np.radians(angle))
        ax.scatter(x, y, s=10, color="gold", edgecolor="darkgoldenrod", linewidth=0.5, zorder=4)

    plt.title("Realistic Lotus Flower with Round Pinched Petals", fontsize=14, fontweight="bold")
    plt.show()

# Call function to draw the lotus
draw_realistic_lotus()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4348\1085000500.py:45: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function to generate Bézier curve points for petals with a round pinched tip
def bezier_curve(points, num=100):
    t = np.linspace(0, 1, num)
    curve = np.array([
        (1 - t) ** 3 * points[0] +
        3 * (1 - t) ** 2 * t * points[1] +
        3 * (1 - t) * t ** 2 * points[2] +
        t ** 3 * points[3]
        for t in t
    ])
    return curve[:, 0], curve[:, 1]

# Function to draw a lotus petal with a round pinched tip
def draw_petal(ax, angle, color, scale=1.0):
    # Adjusted control points for a round pinched tip
    petal_points = np.array([
        [-0.5, 0],   # Base of the petal (wider)
        [0.5, 1.5],  # Control point 1 (right curve)
        [-0.5, 2.5], # Control point 2 (left curve, creates the pinch)
        [0, 3.0]     # Tip of the petal (rounded and pinched)
    ]) * scale

    x, y = bezier_curve(petal_points)

    # Rotate petals
    angle_rad = np.radians(angle)
    x_rot = x * np.cos(angle_rad) - y * np.sin(angle_rad)
    y_rot = x * np.sin(angle_rad) + y * np.cos(angle_rad)

    # Add gradient shading to the petals
    ax.fill(x_rot, y_rot, color=color, alpha=0.9, edgecolor="black", linewidth=0.7)
    ax.plot(x_rot, y_rot, color="black", linewidth=0.5, alpha=0.5)

# Function to draw lotus leaves with veins
def draw_lotus_leaves(ax):
    for scale, color, x_offset, y_offset in [
        (2.5, "darkgreen", 0, -2.8), 
        (2.8, "seagreen", -2, -3.2),
        (3.0, "forestgreen", 2, -3.5)
    ]:
        leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)
        ax.add_patch(leaf)

        # Add veins to the leaves
        for i in range(5):
            vein = plt.Line2D(
                [x_offset - scale * 0.8 + i * 0.4, x_offset + scale * 0.8 - i * 0.4],
                [y_offset - scale * 0.2, y_offset + scale * 0.2],
                color="black", alpha=0.3, linewidth=0.5
            )
            ax.add_line(vein)

# Function to draw the full lotus flower with round pinched petals
def draw_realistic_lotus():
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(-4, 4)
    ax.set_ylim(-4, 4)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    sns.set_style("white")

    # Draw lotus leaves
    draw_lotus_leaves(ax)

    # Draw multiple layers of petals with gradients
    for scale, color, offset in [
        (1.2, "pink", 0), 
        (1.0, "lightpink", 15), 
        (0.8, "palevioletred", 30)
    ]:
        for angle in np.linspace(0, 360, 8, endpoint=False):
            draw_petal(ax, angle + offset, color, scale)

    # Draw the center of the flower with more detail
    ax.scatter(0, 0, s=800, color="yellow", edgecolor="gold", linewidth=2, zorder=3)
    for i in range(50):
        angle = np.random.uniform(0, 360)
        radius = np.random.uniform(0, 0.5)
        x = radius * np.cos(np.radians(angle))
        y = radius * np.sin(np.radians(angle))
        ax.scatter(x, y, s=10, color="gold", edgecolor="darkgoldenrod", linewidth=0.5, zorder=4)

    plt.title("Sayani it is for You", fontsize=14, fontweight="bold")

    # Save the figure as a high-quality image
    plt.savefig("lotusflower.png", dpi=300, bbox_inches="tight", pad_inches=0.5)
    plt.show()

# Call function to draw the lotus
draw_realistic_lotus()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4348\2335532702.py:45: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   leaf = plt.Circle((x_offset, y_offset), scale, color=color, alpha=0.7, edgecolor="black", linewidth=0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt

def lotus_petal(theta, a=1, b=0.6):
    """Parametric function to generate a petal shape"""
    r = a * (1 - np.sin(theta)) ** b
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return x, y

# Create figure
fig, ax = plt.subplots(figsize=(6, 6))

# Generate petals
num_petals = 8  # Number of petals
theta = np.linspace(0, 2 * np.pi, 100)

for i in range(num_petals):
    angle = i * (2 * np.pi / num_petals)
    x, y = lotus_petal(theta)
    
    # Rotate each petal
    x_rot = x * np.cos(angle) - y * np.sin(angle)
    y_rot = x * np.sin(angle) + y * np.cos(angle)
    
    ax.fill(x_rot, y_rot, color="pink", alpha=0.8)

# Add center part of the flower
ax.scatter(0, 0, s=500, color="yellow", edgecolor="gold", linewidth=2, zorder=3)

# Aesthetics
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_xticks([])
ax.set_yticks([])
ax.set_frame_on(False)

plt.title("Lotus Flower in Matplotlib", fontsize=14, fontweight="bold")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def lotus_petal(theta, a=1, b=0.6):
    """Parametric function to generate a petal shape"""
    r = a * (1 - np.sin(theta)) ** b
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return x, y

def clear_lotus(num_petals=8, petal_color="pink", center_color="yellow", center_edge_color="gold", center_size=500, alpha=0.8):
    """Generates a clear lotus flower with customizable parameters."""

    fig, ax = plt.subplots(figsize=(8, 8))  # Increase figure size for better clarity

    theta = np.linspace(0, 2 * np.pi, 200)  # Increase points for smoother petals

    for i in range(num_petals):
        angle = i * (2 * np.pi / num_petals)
        x, y = lotus_petal(theta)

        x_rot = x * np.cos(angle) - y * np.sin(angle)
        y_rot = x * np.sin(angle) + y * np.cos(angle)

        ax.fill(x_rot, y_rot, color=petal_color, alpha=alpha, edgecolor="none") #remove edge color

    ax.scatter(0, 0, s=center_size, color=center_color, edgecolor=center_edge_color, linewidth=2, zorder=3)

    ax.set_xlim(-1.5, 1.5)
    ax.set_ylim(-1.5, 1.5)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_aspect("equal") #ensure a circular shape
    ax.set_frame_on(False)

    plt.title("Clear Lotus Flower", fontsize=16, fontweight="bold") #increase fontsize
    plt.show()

# Example usage with clear parameters:
clear_lotus(num_petals=8, petal_color="lightcoral", center_color="gold", center_edge_color="orange", center_size=600, alpha=0.9)
clear_lotus(num_petals=10, petal_color="lightblue", center_color="yellow", center_edge_color="darkgoldenrod", center_size=400, alpha=0.7)
clear_lotus(num_petals=6, petal_color="thistle", center_color="khaki", center_edge_color="olive", center_size=500, alpha=0.85)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

def lotus_petal(theta, a=1, b=0.7, c=0.1):  # Added 'c' for shape control
    """Parametric function for a more realistic petal shape."""
    r = a * (1 - c * np.cos(theta)) * (1 - np.sin(theta))**b
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return x, y

def create_petal_gradient(color1, color2):
    """Creates a linear color gradient colormap."""
    return LinearSegmentedColormap.from_list("petal_gradient", [color1, color2])

def draw_lotus(num_petals=12, petal_color1="pink", petal_color2="lightpink",
               center_color="yellow", center_outline="gold", center_size=400):
    """Draws a lotus flower with gradients and layering."""

    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_aspect("equal")
    ax.axis("off")

    theta = np.linspace(0, 2 * np.pi, 200)
    petal_cmap = create_petal_gradient(petal_color1, petal_color2)

    # Draw petals in layers (inner to outer)
    num_layers = 3
    petals_per_layer = num_petals // num_layers

    for layer in range(num_layers):
        for i in range(petals_per_layer):
            petal_index = layer * petals_per_layer + i
            angle = petal_index * (2 * np.pi / num_petals)

            x, y = lotus_petal(theta)  # Use the refined petal function

            x_rot = x * np.cos(angle) - y * np.sin(angle)
            y_rot = x * np.sin(angle) + y * np.cos(angle)

            # Apply a gradient to each petal
            norm = plt.Normalize(0, len(x_rot))  # Normalize for gradient
            ax.scatter(x_rot, y_rot, c=norm(np.arange(len(x_rot))), cmap=petal_cmap, s=30, zorder=2 - layer)  # Smaller points for smoother gradient

    # Draw the center
    ax.scatter(0, 0, s=center_size, color=center_color,
               edgecolor=center_outline, linewidth=1.5, zorder=3)

    plt.title("Lotus Flower with Gradient", fontsize=16, fontweight="bold")
    plt.show()

# Example usage:
draw_lotus(num_petals=12, petal_color1="#E91E63", petal_color2="#F8BBD0",  # Deep pink to light pink
           center_color="yellow", center_outline="orange", center_size=500)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

def lotus_petal(theta, a=1, b=0.7, c=0.2, d=0.05):
    """Refined petal function with more shape control."""
    r = a * (1 - d * np.cos(theta * 3)) * (1 - c * np.cos(theta)) * (1 - np.sin(theta))**b
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return x, y

def create_radial_gradient(color1, color2):
    """Creates a radial gradient colormap (approximation)."""
    # This is a simplified approximation. True radial gradients are harder in matplotlib.
    return LinearSegmentedColormap.from_list("radial_gradient", [color2, color1, color2])

def draw_realistic_lotus(num_petals=18, petal_color1="#F8BBD0", petal_color2="#E91E63",
                         center_color1="#FFEB3B", center_color2="#FDD835",
                         center_outline="#FFA000", center_size=500):
    """Draws a more realistic lotus flower."""

    fig, ax = plt.subplots(figsize=(10, 10))  # Larger figure for detail
    ax.set_aspect("equal")
    ax.axis("off")

    theta = np.linspace(0, 2 * np.pi, 250)  # More points for smoothness
    petal_cmap = create_radial_gradient(petal_color1, petal_color2)

    # Layered petals with variations
    num_layers = 3
    petals_per_layer = num_petals // num_layers
    
    np.random.seed(42)  # For consistent variation

    for layer in range(num_layers):
        for i in range(petals_per_layer):
            petal_index = layer * petals_per_layer + i
            angle = petal_index * (2 * np.pi / num_petals)
            
            # Introduce slight random variations
            scale_factor = 1.0 + np.random.normal(0, 0.05)  # Petal size variation
            shape_c = 0.2 + np.random.normal(0, 0.03)  # Shape variation
            
            x, y = lotus_petal(theta, a=scale_factor, c=shape_c)

            x_rot = x * np.cos(angle) - y * np.sin(angle)
            y_rot = x * np.sin(angle) + y * np.cos(angle)

            # Gradient with a bit more emphasis
            norm = plt.Normalize(0, len(x_rot))
            ax.scatter(x_rot, y_rot, c=norm(np.arange(len(x_rot))), cmap=petal_cmap, s=30, zorder=2 - layer)

    # Detailed center
    center_cmap = create_radial_gradient(center_color1, center_color2)
    center_theta = np.linspace(0, 2 * np.pi, 100)
    center_r = 0.2  # Size of the center
    center_x = center_r * np.cos(center_theta)
    center_y = center_r * np.sin(center_theta)
    ax.fill(center_x, center_y, color=center_color1, zorder=3)  # Base center

    # Add some variation to the center (simplified stamen effect)
    num_stamen = 15
    for i in range(num_stamen):
        stamen_angle = i * (2 * np.pi / num_stamen)
        stamen_r = 0.25 + np.random.rand() * 0.05
        stamen_x = stamen_r * np.cos(stamen_angle)
        stamen_y = stamen_r * np.sin(stamen_angle)
        ax.scatter(stamen_x, stamen_y, color=center_outline, s=20, zorder=4)

    ax.scatter(0, 0, s=center_size // 4, color=center_color2,
               edgecolor=center_outline, linewidth=1.5, zorder=3)  # Inner center

    plt.title("Realistic Lotus Flower", fontsize=16, fontweight="bold")
    plt.show()

# Example usage:
draw_realistic_lotus()
